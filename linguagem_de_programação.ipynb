# %% [markdown]
# <a href="https://colab.research.google.com/github/adrianoqa/logica-com-python/blob/main/linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
#1.nosso primeiro programa
print ("hello world")
# Out:
# hello world

# %%
#2. Criando variaveis de tipos diferentes
x = 10
nome = 'Adriano'
nota = 8.75
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Adriano
# 8.75
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("Digite seu nome:")
# Out:
# Digite seu nome:adriano

# %%
print(f"Ola {nome}, bem vindo á disciplina de programção")
# Out:
# Ola adriano, bem vindo á disciplina de programção

# %%
nota_1 = int(input("DIGIRE A NOTA: "))
nota_2 = int(input("DIGIRE A NOTA: "))
nota_3 = int(input("DIGIRE A NOTA: "))
nota_4 = int(input("DIGIRE A NOTA: "))
# Out:
# DIGIRE A NOTA: 9
# DIGIRE A NOTA: 1
# DIGIRE A NOTA: 3
# DIGIRE A NOTA: 4

# %%
media = (nota_1+nota_2+nota_3+nota_4)/4

# %%
print(media)
# Out:
# 4.25

# %%
if media >= 6:
     situacao = "Aprovado"
else:
     situacao = "Reprovado"

# %%
print(situacao)
# Out:
# Reprovado
